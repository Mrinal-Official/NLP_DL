# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)

# %%
corpus = """Hello Welcome, to Krish Naik's NLP Turorials.
Please so watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to Krish Naik's NLP Turorials.
# Please so watch the entire course! to become expert in NLP.

# %%
# Tokenization
# Sentence--> paragraphs

import nltk
nltk.download('punkt_tab')

from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
sent_tokenize(corpus)
# Out:
# ["Hello Welcome, to Krish Naik's NLP Turorials.",
#  'Please so watch the entire course!',
#  'to become expert in NLP.']

# %%
documents = sent_tokenize(corpus)
print(documents, type(documents))
# Out:
# ["Hello Welcome, to Krish Naik's NLP Turorials.", 'Please so watch the entire course!', 'to become expert in NLP.'] <class 'list'>

# %%
for sentences in documents:
    print(sentences)
# Out:
# Hello Welcome, to Krish Naik's NLP Turorials.
# Please so watch the entire course!
# to become expert in NLP.

# %%
# Paragraph --> words
# sentece --> words

from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Turorials',
#  '.',
#  'Please',
#  'so',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'Turorials',
#  '.',
#  'Please',
#  'so',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Turorials.',
#  'Please',
#  'so',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
